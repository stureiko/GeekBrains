# %% [markdown]
# ## Author: Стурейко Игорь
# ### Course: Geekbrains.DataLibraries.2
# ### Project: Lesson_02
# ### Date: 2020-10-12

# %% [markdown]
# ## Задание 1 В чём различие между зависимыми и независимыми выборками?

# %% [markdown]
# Независимые выборки - сравниваются две разные группы, например мужчины и женщины, молодые и пожилые и т.д.
# Независимые выборки характеризуются тем, что вероятность отбора любого испытуемого одной выборки не зависит от отбора любого из испытуемых другой выборки.
#
# Напротив, зависимые выборки характеризуются тем, что каждому испытуемому одной выборки поставлен в соответствие по определенному критерию испытуемый из другой выборки. Зависимые выборки как правило возникают, когда речь идет об одной группе испытуемых до и после эксперементального воздействия.

# %% [markdown]
# ## Задание 2 Когда применяются параметрические статистические критерии, а когда — их непараметрические аналоги?

# %% [markdown]
# Непераметрические статистические критерии применяются для определения принадлежности выборки какому либо закону распределения, например нормальному.
# А параметрические для определения параметров распределения - мат.ожидания, дисперсии.
